# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## n = 100, e = 0

# %%
df_lr = pd.read_csv('./res/ks/lr_n100.csv')
df_rf = pd.read_csv('./res/ks/rf_n100.csv')
df_spo = pd.read_csv('./res/ks/spoplus_n100.csv')
df_spor = pd.read_csv('./res/ks/spoplusrel_n100.csv')
df_bb = pd.read_csv('./res/ks/blackbox_n100.csv')

# %%
# draw boxplot
plt.figure(figsize=(15,6))
plt.boxplot(df_lr, boxprops=dict(facecolor='g', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])-0.36, widths=0.12)
plt.boxplot(df_rf, boxprops=dict(facecolor='r', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])-0.18, widths=0.12)
plt.boxplot(df_spo, boxprops=dict(facecolor='c', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1]), widths=0.12)
plt.boxplot(df_spor, boxprops=dict(facecolor='y', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])+0.18, widths=0.12)
plt.boxplot(df_bb, boxprops=dict(facecolor='m', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])+0.36, widths=0.12)
plt.xlabel('Deg', fontsize=16)
plt.xticks(ticks=[0,1,2,3], labels=[1,2,4,6], fontsize=12)
plt.ylabel('Normalized SPO Loss', fontsize=16)
plt.yticks(fontsize=12)
plt.ylim(-0.05, 0.3)
plt.title('Training Set Size = 100,\nNoise Half−width = 0')
plt.legend(['2-stage LR', '2-stage RF', 'SPO+', 'SPO+ Relax', 'Black-Box'], labelcolor=['g', 'r', 'c', 'y', 'm'])
plt.show()

# %% [markdown]
# ## n = 100, e = 0.5

# %%
df_lr = pd.read_csv('./res/ks/lr_n100_noise.csv')
df_rf = pd.read_csv('./res/ks/rf_n100_noise.csv')
df_spo = pd.read_csv('./res/ks/spoplus_n100_noise.csv')
df_spor = pd.read_csv('./res/ks/spoplusrel_n100_noise.csv')
df_bb = pd.read_csv('./res/ks/blackbox_n100_noise.csv')

# %%
# draw boxplot
plt.figure(figsize=(15,6))
plt.boxplot(df_lr, boxprops=dict(facecolor='g', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])-0.36, widths=0.12)
plt.boxplot(df_rf, boxprops=dict(facecolor='r', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])-0.18, widths=0.12)
plt.boxplot(df_spo, boxprops=dict(facecolor='c', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1]), widths=0.12)
plt.boxplot(df_spor, boxprops=dict(facecolor='y', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])+0.18, widths=0.12)
plt.boxplot(df_bb, boxprops=dict(facecolor='m', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])+0.36, widths=0.12)
plt.xlabel('Deg', fontsize=16)
plt.xticks(ticks=[0,1,2,3], labels=[1,2,4,6], fontsize=12)
plt.ylabel('Normalized SPO Loss', fontsize=16)
plt.yticks(fontsize=12)
plt.ylim(-0.05, 0.3)
plt.title('Training Set Size = 100,\nNoise Half−width = 0.5')
plt.legend(['2-stage LR', '2-stage RF', 'SPO+', 'SPO+ Relax', 'Black-Box'], labelcolor=['g', 'r', 'c', 'y', 'm'])
plt.show()

# %% [markdown]
# # n = 1000, e = 0

# %%
df_lr = pd.read_csv('./res/ks/lr_n1000.csv')
df_rf = pd.read_csv('./res/ks/rf_n1000.csv')
df_spo = pd.read_csv('./res/ks/spoplus_n1000.csv')
df_spor = pd.read_csv('./res/ks/spoplusrel_n1000.csv')
df_bb = pd.read_csv('./res/ks/blackbox_n1000.csv')

# %%
# draw boxplot
plt.figure(figsize=(15,6))
plt.boxplot(df_lr, boxprops=dict(facecolor='g', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])-0.36, widths=0.12)
plt.boxplot(df_rf, boxprops=dict(facecolor='r', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])-0.18, widths=0.12)
plt.boxplot(df_spo, boxprops=dict(facecolor='c', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1]), widths=0.12)
plt.boxplot(df_spor, boxprops=dict(facecolor='y', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])+0.18, widths=0.12)
plt.boxplot(df_bb, boxprops=dict(facecolor='m', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])+0.36, widths=0.12)
plt.xlabel('Deg', fontsize=16)
plt.xticks(ticks=[0,1,2,3], labels=[1,2,4,6], fontsize=12)
plt.ylabel('Normalized SPO Loss', fontsize=16)
plt.yticks(fontsize=12)
plt.ylim(-0.05, 0.3)
plt.title('Training Set Size = 1000,\nNoise Half−width = 0')
plt.legend(['2-stage LR', '2-stage RF', 'SPO+', 'SPO+ Relax', 'Black-Box'], labelcolor=['g', 'r', 'c', 'y', 'm'])
plt.show()

# %% [markdown]
# ## n = 1000, e = 0.5

# %%
df_lr = pd.read_csv('./res/ks/lr_n1000_noise.csv')
df_rf = pd.read_csv('./res/ks/rf_n1000_noise.csv')
df_spo = pd.read_csv('./res/ks/spoplus_n1000_noise.csv')
df_spor = pd.read_csv('./res/ks/spoplusrel_n1000_noise.csv')
df_bb = pd.read_csv('./res/ks/blackbox_n1000_noise.csv')

# %%
# draw boxplot
plt.figure(figsize=(15,6))
plt.boxplot(df_lr, boxprops=dict(facecolor='g', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])-0.36, widths=0.12)
plt.boxplot(df_rf, boxprops=dict(facecolor='r', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])-0.18, widths=0.12)
plt.boxplot(df_spo, boxprops=dict(facecolor='c', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1]), widths=0.12)
plt.boxplot(df_spor, boxprops=dict(facecolor='y', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])+0.18, widths=0.12)
plt.boxplot(df_bb, boxprops=dict(facecolor='m', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])+0.36, widths=0.12)
plt.xlabel('Deg', fontsize=16)
plt.xticks(ticks=[0,1,2,3], labels=[1,2,4,6], fontsize=12)
plt.ylabel('Normalized SPO Loss', fontsize=16)
plt.yticks(fontsize=12)
plt.ylim(-0.05, 0.3)
plt.title('Training Set Size = 1000,\nNoise Half−width = 0.5')
plt.legend(['2-stage LR', '2-stage RF', 'SPO+', 'SPO+ Relax', 'Black-Box'], labelcolor=['g', 'r', 'c', 'y', 'm'])
plt.show()
