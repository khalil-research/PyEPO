# %%
# set work dir
import os
os.chdir("../pkg")

# %%
import time
import copy
import pyepo
import torch
from torch import nn
from torch.utils.data import DataLoader
from matplotlib import pyplot as plt
import scienceplots
plt.style.reload_library()
plt.style.use("science")
from matplotlib import ticker
import tol_colors as tc
import numpy as np
from tqdm import tqdm
torch.manual_seed(135)
from sklearn.model_selection import train_test_split
# Out:
# Auto-Sklearn cannot be imported.

# %%
# linear model
class LinearRegression(nn.Module):
    
    def __init__(self, indim, outdim):
        super(LinearRegression, self).__init__()
        self.linear = nn.Linear(indim, outdim)
    
    def forward(self, x):
        out = self.linear(x)
        return out

# %%
def train_h(optmodel, reg, trainloader, testloader, lr, num_epochs=300, lambd=20):
    # cuda
    if torch.cuda.is_available():
        reg = reg.cuda()
    # set optimizer
    optimizer = torch.optim.Adam(reg.parameters(), lr=lr)
    # set dbb optimizer
    dbb = pyepo.func.blackboxOpt(optmodel, lambd=lambd, processes=4)
    # set loss
    criterion = nn.L1Loss()
    # train model
    reg.train()
    loss_log = []
    grad_log = []
    regret = pyepo.metric.regret(reg, optmodel, testloader)
    regret_log = [regret]
    print("Epoch   0, Loss: Unknown, Regret: {:7.4f}%".format(regret*100))
    for epoch in range(num_epochs):
        # load data
        for i, data in enumerate(trainloader):
            x, c, w, z = data
            # cuda
            if torch.cuda.is_available():
                x, c, w, z = x.cuda(), c.cuda(), w.cuda(), z.cuda()
            # linear regression
            cp = reg(x)
            # black-box optimizer
            wp = dbb(cp)
            # loss
            loss = criterion(wp, w)
            # add hook
            abs_grad = []
            cp.register_hook(lambda grad: abs_grad.append(torch.abs(grad).mean().item()))
            # backward pass
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            # add log
            loss_log.append(loss.item())
            grad_log.append(abs_grad[0])
        if epoch % 5 == 0:
            # true regret
            regret = pyepo.metric.regret(reg, optmodel, testloader)
            regret_log.append(regret)
            print("Epoch {:3}, Loss: {:7.4f}, Regret: {:7.4f}%".format(epoch, loss.item(), regret*100))
    drawplot(num_epochs, grad_log, loss_log)
    return regret_log

# %%
def train_r(optmodel, reg, trainloader, testloader, lr, num_epochs=300, lambd=20):
    # cuda
    if torch.cuda.is_available():
        reg = reg.cuda()
    # set optimizer
    optimizer = torch.optim.Adam(reg.parameters(), lr=lr)
    # set dbb optimizer
    dbb = pyepo.func.blackboxOpt(optmodel, lambd=lambd, processes=4)
    # set loss
    criterion = nn.L1Loss()
    # train model
    reg.train()
    regret = pyepo.metric.regret(reg, optmodel, testloader)
    regret_log = [regret]
    print("Epoch   0, Loss: Unknown, Regret: {:7.4f}%".format(regret*100))
    for epoch in range(num_epochs):
        # load data
        for i, data in enumerate(trainloader):
            x, c, w, z = data
            # cuda
            if torch.cuda.is_available():
                x, c, w, z = x.cuda(), c.cuda(), w.cuda(), z.cuda()
            # linear regression
            cp = reg(x)
            # black-box optimizer
            wp = dbb(cp)
            # objective value
            zp = (wp * c).sum(1).view(-1, 1)
            # loss
            loss = criterion(zp, z)
            # backward pass
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        if epoch % 5 == 0:
            # true regret
            regret = pyepo.metric.regret(reg, optmodel, testloader)
            regret_log.append(regret)
            print("Epoch {:3}, Loss: {:7.4f}, Regret: {:7.4f}%".format(epoch, loss.item(), regret*100))
    return regret_log

# %%
def drawplot(num_epochs, grad_log, loss_log):
    # loss
    fig = plt.figure(figsize=(16, 8))
    plt.plot(loss_log, color="c", lw=2)
    plt.xticks(fontsize=28)
    plt.yticks(fontsize=28)
    plt.xlabel("Iters", fontsize=36)
    plt.ylabel("Loss", fontsize=36)
    plt.title("Learning Curve", fontsize=36)
    plt.show()
    # abs grad
    fig = plt.figure(figsize=(16, 8))
    plt.plot(grad_log, color="c", lw=2)
    plt.xticks(fontsize=28)
    plt.yticks(fontsize=28)
    plt.xlabel("Iters", fontsize=36)
    plt.ylabel("Abs Grad", fontsize=36)
    plt.title("Learning Curve", fontsize=36)
    plt.show()

# %% [markdown]
# ## Shortest Path

# %%
# init data
grid = (5,5) # grid graph
n = 1000 # number of data
p = 5 # size of feature
deg = 4 # polynomial degree
e = 0.5 # noise half-width
x, c = pyepo.data.shortestpath.genData(n+1000, p, grid, deg=deg, noise_width=e)

# %%
# optimization model 
sp_model = pyepo.model.grb.shortestPathModel(grid)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-07-09

# %%
# prediction model
reg = LinearRegression(p, (grid[0]-1)*grid[1]+(grid[1]-1)*grid[0])

# %%
# dataset
x_train, x_test, c_train, c_test = train_test_split(x, c, test_size=1000, random_state=246)
sp_dataset_train = pyepo.data.dataset.optDataset(sp_model, x_train, c_train)
sp_dataset_test = pyepo.data.dataset.optDataset(sp_model, x_test, c_test)
# data loader
batch_size = 32
sp_loader_train = DataLoader(sp_dataset_train, batch_size=batch_size, shuffle=True)
sp_loader_test = DataLoader(sp_dataset_test, batch_size=batch_size, shuffle=False)
# Out:
# Optimizing for optDataset...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 1138.08it/s]
# Optimizing for optDataset...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 1114.60it/s]

# %%
# train
loss_h = train_h(sp_model, copy.deepcopy(reg), sp_loader_train, sp_loader_test, lr=5e-3)
# Out:
# Num of cores: 4
# Epoch   0, Loss: Unknown, Regret: 52.0637%
# Epoch   0, Loss:  0.2875, Regret: 44.2693%
# Epoch   5, Loss:  0.2562, Regret: 34.0913%
# Epoch  10, Loss:  0.2375, Regret: 27.1244%
# Epoch  15, Loss:  0.1562, Regret: 18.6017%
# Epoch  20, Loss:  0.0625, Regret: 12.8788%
# Epoch  25, Loss:  0.1063, Regret: 13.2347%
# Epoch  30, Loss:  0.1500, Regret: 13.2056%
# Epoch  35, Loss:  0.1875, Regret: 11.8401%
# Epoch  40, Loss:  0.1750, Regret: 11.8953%
# Epoch  45, Loss:  0.1313, Regret: 12.3999%
# Epoch  50, Loss:  0.1437, Regret: 11.7551%
# Epoch  55, Loss:  0.1375, Regret: 12.2952%
# Epoch  60, Loss:  0.1938, Regret: 12.2958%
# Epoch  65, Loss:  0.0938, Regret: 12.0925%
# Epoch  70, Loss:  0.1625, Regret: 11.4865%
# Epoch  75, Loss:  0.1375, Regret: 11.9286%
# Epoch  80, Loss:  0.1750, Regret: 12.0982%
# Epoch  85, Loss:  0.1375, Regret: 12.0429%
# Epoch  90, Loss:  0.1500, Regret: 11.1184%
# Epoch  95, Loss:  0.1750, Regret: 12.2058%
# Epoch 100, Loss:  0.2313, Regret: 12.0642%
# Epoch 105, Loss:  0.1437, Regret: 11.8035%
# Epoch 110, Loss:  0.1625, Regret: 12.2943%
# Epoch 115, Loss:  0.1063, Regret: 12.0833%
# Epoch 120, Loss:  0.1000, Regret: 11.3678%
# Epoch 125, Loss:  0.1000, Regret: 12.1889%
# Epoch 130, Loss:  0.1313, Regret: 12.1235%
# Epoch 135, Loss:  0.0688, Regret: 11.2408%
# Epoch 140, Loss:  0.1938, Regret: 11.2041%
# Epoch 145, Loss:  0.2062, Regret: 11.0059%
# Epoch 150, Loss:  0.0938, Regret: 11.2731%
# Epoch 155, Loss:  0.1000, Regret: 11.4160%
# Epoch 160, Loss:  0.1562, Regret: 10.9547%
# Epoch 165, Loss:  0.0938, Regret: 10.9356%
# Epoch 170, Loss:  0.1000, Regret: 10.6767%
# Epoch 175, Loss:  0.1562, Regret: 10.8344%
# Epoch 180, Loss:  0.1187, Regret: 10.8034%
# Epoch 185, Loss:  0.2438, Regret: 10.5546%
# Epoch 190, Loss:  0.1063, Regret: 10.6231%
# Epoch 195, Loss:  0.2562, Regret: 11.0434%
# Epoch 200, Loss:  0.1625, Regret: 10.7316%
# Epoch 205, Loss:  0.1125, Regret: 11.5001%
# Epoch 210, Loss:  0.0813, Regret: 11.5170%
# Epoch 215, Loss:  0.1187, Regret: 11.1772%
# Epoch 220, Loss:  0.1250, Regret: 11.1134%
# Epoch 225, Loss:  0.0750, Regret: 11.2954%
# Epoch 230, Loss:  0.1000, Regret: 11.5039%
# Epoch 235, Loss:  0.1063, Regret: 10.9134%
# Epoch 240, Loss:  0.1250, Regret: 11.6465%
# Epoch 245, Loss:  0.1187, Regret: 11.3679%
# Epoch 250, Loss:  0.0750, Regret: 11.5109%
# Epoch 255, Loss:  0.0813, Regret: 10.8227%
# Epoch 260, Loss:  0.1187, Regret: 11.2167%
# Epoch 265, Loss:  0.1750, Regret: 11.6009%
# Epoch 270, Loss:  0.1063, Regret: 11.3719%
# Epoch 275, Loss:  0.0875, Regret: 11.7435%
# Epoch 280, Loss:  0.1625, Regret: 11.3258%
# Epoch 285, Loss:  0.1063, Regret: 11.1574%
# Epoch 290, Loss:  0.1750, Regret: 11.5344%
# Epoch 295, Loss:  0.0750, Regret: 11.3651%

# %%
# train
loss_r = train_r(sp_model, copy.deepcopy(reg), sp_loader_train, sp_loader_test, lr=5e-3)
# Out:
# Num of cores: 4
# Epoch   0, Loss: Unknown, Regret: 52.0637%
# Epoch   0, Loss:  0.6997, Regret: 33.9711%
# Epoch   5, Loss:  0.8015, Regret: 11.3125%
# Epoch  10, Loss:  0.9230, Regret: 12.0384%
# Epoch  15, Loss:  0.2301, Regret: 15.5931%
# Epoch  20, Loss:  0.7510, Regret: 16.2449%
# Epoch  25, Loss:  0.6744, Regret: 19.5981%
# Epoch  30, Loss:  0.5233, Regret: 15.8446%
# Epoch  35, Loss:  0.2912, Regret: 14.3174%
# Epoch  40, Loss:  0.3006, Regret: 16.4950%
# Epoch  45, Loss:  0.2989, Regret: 17.2524%
# Epoch  50, Loss:  1.0403, Regret: 24.3184%
# Epoch  55, Loss:  0.6169, Regret: 19.7185%
# Epoch  60, Loss:  0.5108, Regret: 16.3984%
# Epoch  65, Loss:  0.4933, Regret: 15.5196%
# Epoch  70, Loss:  0.6117, Regret: 16.7402%
# Epoch  75, Loss:  0.8042, Regret: 18.4721%
# Epoch  80, Loss:  1.1309, Regret: 13.4359%
# Epoch  85, Loss:  0.1906, Regret: 13.7791%
# Epoch  90, Loss:  0.9428, Regret: 20.4486%
# Epoch  95, Loss:  0.3947, Regret: 16.4070%
# Epoch 100, Loss:  0.7980, Regret: 19.7700%
# Epoch 105, Loss:  0.1256, Regret: 16.1902%
# Epoch 110, Loss:  0.5683, Regret: 16.5062%
# Epoch 115, Loss:  0.4563, Regret: 19.2269%
# Epoch 120, Loss:  0.5229, Regret: 16.8896%
# Epoch 125, Loss:  0.4945, Regret: 12.2412%
# Epoch 130, Loss:  0.8988, Regret: 14.9249%
# Epoch 135, Loss:  0.4320, Regret: 17.5174%
# Epoch 140, Loss:  0.2165, Regret: 16.1090%
# Epoch 145, Loss:  0.2130, Regret: 14.4805%
# Epoch 150, Loss:  1.1493, Regret: 15.5307%
# Epoch 155, Loss:  0.4734, Regret: 16.1277%
# Epoch 160, Loss:  0.2485, Regret: 16.2641%
# Epoch 165, Loss:  0.4577, Regret: 16.5195%
# Epoch 170, Loss:  0.5697, Regret: 16.0057%
# Epoch 175, Loss:  0.2621, Regret: 18.0054%
# Epoch 180, Loss:  0.5244, Regret: 15.8375%
# Epoch 185, Loss:  0.3480, Regret: 23.2970%
# Epoch 190, Loss:  1.3326, Regret: 21.0922%
# Epoch 195, Loss:  0.6419, Regret: 15.1847%
# Epoch 200, Loss:  0.5136, Regret: 20.0803%
# Epoch 205, Loss:  0.2136, Regret: 16.8437%
# Epoch 210, Loss:  0.4570, Regret: 15.9161%
# Epoch 215, Loss:  0.6129, Regret: 18.1000%
# Epoch 220, Loss:  0.2649, Regret: 12.8439%
# Epoch 225, Loss:  0.1514, Regret: 14.4952%
# Epoch 230, Loss:  0.2562, Regret: 22.4151%
# Epoch 235, Loss:  0.2941, Regret: 15.9775%
# Epoch 240, Loss:  0.4854, Regret: 12.8155%
# Epoch 245, Loss:  0.2826, Regret: 15.9270%
# Epoch 250, Loss:  0.2766, Regret: 15.6539%
# Epoch 255, Loss:  0.5723, Regret: 18.8703%
# Epoch 260, Loss:  0.4496, Regret: 14.8972%
# Epoch 265, Loss:  1.3233, Regret: 16.8607%
# Epoch 270, Loss:  0.7634, Regret: 17.1873%
# Epoch 275, Loss:  0.3975, Regret: 19.0507%
# Epoch 280, Loss:  0.9689, Regret: 22.7415%
# Epoch 285, Loss:  0.4485, Regret: 14.4532%
# Epoch 290, Loss:  0.5940, Regret: 17.5329%
# Epoch 295, Loss:  0.6729, Regret: 15.0249%

# %%
# color map
cset =  tc.tol_cset('light')
colors = [cset.light_blue, cset.light_cyan]
# draw plot
fig = plt.figure(figsize=(16, 8))
plt.plot(range(0, 305, 5), loss_r, color=cset.light_blue, ls="-", lw=5, label="DBB")
plt.plot(range(0, 305, 5), loss_h, color=cset.light_cyan, ls=":", lw=5, label="DBB H")
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)
plt.xlabel("Epoch", fontsize=36)
plt.ylabel("Loss", fontsize=36)
plt.title("Shortest Path", fontsize=36)
plt.legend(fontsize=32)
plt.show()
#fig.savefig("./images/hamming-sp.pdf", dpi=300)

# %% [markdown]
# ## 2D Knapsack

# %%
# init data
m = 48 # number of items
n = 100 # number of data
p = 5 # size of feature
deg = 4 # polynomial degree
dim = 2 # dimension of knapsack
noise_width = 0.5 # noise half-width
caps = [30] * dim # capacity
weights, x, c = pyepo.data.knapsack.genData(n+1000, p, m, deg=deg, dim=dim, noise_width=noise_width)

# %%
# optimization model 
ks_model = pyepo.model.grb.knapsackModel(weights, caps)

# %%
# prediction model
reg = LinearRegression(p, m)

# %%
# dataset
x_train, x_test, c_train, c_test = train_test_split(x, c, test_size=1000, random_state=246)
ks_dataset_train = pyepo.data.dataset.optDataset(ks_model, x_train, c_train)
ks_dataset_test = pyepo.data.dataset.optDataset(ks_model, x_test, c_test)
# data loader
batch_size = 32
ks_loader_train = DataLoader(ks_dataset_train, batch_size=batch_size, shuffle=True)
ks_loader_test = DataLoader(ks_dataset_test, batch_size=batch_size, shuffle=False)
# Out:
# Optimizing for optDataset...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 302.97it/s]
# Optimizing for optDataset...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:03<00:00, 296.91it/s]

# %%
# train
loss_h = train_h(ks_model, copy.deepcopy(reg), ks_loader_train, ks_loader_test, lr=5e-2)
# Out:
# Num of cores: 4
# Epoch   0, Loss: Unknown, Regret: 52.6396%
# Epoch   0, Loss:  0.2292, Regret: 52.6396%
# Epoch   5, Loss:  0.1927, Regret: 52.6396%
# Epoch  10, Loss:  0.1979, Regret: 52.6396%
# Epoch  15, Loss:  0.2500, Regret: 52.6396%
# Epoch  20, Loss:  0.2188, Regret: 52.6396%
# Epoch  25, Loss:  0.1875, Regret: 52.6396%
# Epoch  30, Loss:  0.2083, Regret: 52.6396%
# Epoch  35, Loss:  0.2135, Regret: 52.6396%
# Epoch  40, Loss:  0.2135, Regret: 52.6396%
# Epoch  45, Loss:  0.2083, Regret: 52.6396%
# Epoch  50, Loss:  0.2083, Regret: 52.6396%
# Epoch  55, Loss:  0.2083, Regret: 52.6396%
# Epoch  60, Loss:  0.2188, Regret: 52.6396%
# Epoch  65, Loss:  0.2135, Regret: 52.6396%
# Epoch  70, Loss:  0.2135, Regret: 52.6396%
# Epoch  75, Loss:  0.2031, Regret: 52.6396%
# Epoch  80, Loss:  0.2240, Regret: 52.6396%
# Epoch  85, Loss:  0.2031, Regret: 52.6396%
# Epoch  90, Loss:  0.2083, Regret: 52.6396%
# Epoch  95, Loss:  0.2031, Regret: 52.6396%
# Epoch 100, Loss:  0.2083, Regret: 52.6396%
# Epoch 105, Loss:  0.1875, Regret: 52.6396%
# Epoch 110, Loss:  0.1771, Regret: 52.6396%
# Epoch 115, Loss:  0.1979, Regret: 52.6396%
# Epoch 120, Loss:  0.2135, Regret: 52.6396%
# Epoch 125, Loss:  0.2135, Regret: 52.6396%
# Epoch 130, Loss:  0.2031, Regret: 52.6396%
# Epoch 135, Loss:  0.2135, Regret: 52.6396%
# Epoch 140, Loss:  0.2344, Regret: 52.6396%
# Epoch 145, Loss:  0.1979, Regret: 52.6396%
# Epoch 150, Loss:  0.2135, Regret: 52.6396%
# Epoch 155, Loss:  0.2188, Regret: 52.6396%
# Epoch 160, Loss:  0.2240, Regret: 52.6396%
# Epoch 165, Loss:  0.1979, Regret: 52.6396%
# Epoch 170, Loss:  0.2240, Regret: 52.6396%
# Epoch 175, Loss:  0.1927, Regret: 52.6396%
# Epoch 180, Loss:  0.1927, Regret: 52.6396%
# Epoch 185, Loss:  0.1979, Regret: 52.6396%
# Epoch 190, Loss:  0.2083, Regret: 52.6396%
# Epoch 195, Loss:  0.2240, Regret: 52.6396%
# Epoch 200, Loss:  0.2083, Regret: 52.6396%
# Epoch 205, Loss:  0.2344, Regret: 52.6396%
# Epoch 210, Loss:  0.2292, Regret: 52.6396%
# Epoch 215, Loss:  0.1927, Regret: 52.6396%
# Epoch 220, Loss:  0.2135, Regret: 52.6396%
# Epoch 225, Loss:  0.1979, Regret: 52.6396%
# Epoch 230, Loss:  0.2031, Regret: 52.6396%
# Epoch 235, Loss:  0.2240, Regret: 52.6396%
# Epoch 240, Loss:  0.2031, Regret: 52.6396%
# Epoch 245, Loss:  0.2396, Regret: 52.6396%
# Epoch 250, Loss:  0.2031, Regret: 52.6396%
# Epoch 255, Loss:  0.2135, Regret: 52.6396%
# Epoch 260, Loss:  0.1875, Regret: 52.6396%
# Epoch 265, Loss:  0.2292, Regret: 52.6396%
# Epoch 270, Loss:  0.2188, Regret: 52.6396%
# Epoch 275, Loss:  0.2135, Regret: 52.6396%
# Epoch 280, Loss:  0.1719, Regret: 52.6396%
# Epoch 285, Loss:  0.2344, Regret: 52.6396%
# Epoch 290, Loss:  0.2083, Regret: 52.6396%
# Epoch 295, Loss:  0.1823, Regret: 52.6396%

# %%
# train
loss_r = train_r(ks_model, copy.deepcopy(reg), ks_loader_train, ks_loader_test, lr=5e-2)
# Out:
# Num of cores: 4
# Epoch   0, Loss: Unknown, Regret: 52.6396%
# Epoch   0, Loss: 42.0000, Regret: 48.2332%
# Epoch   5, Loss: 37.5000, Regret: 37.8205%
# Epoch  10, Loss: 31.2500, Regret: 31.3817%
# Epoch  15, Loss: 10.5000, Regret: 26.9754%
# Epoch  20, Loss: 15.7500, Regret: 24.4197%
# Epoch  25, Loss:  8.7500, Regret: 23.5267%
# Epoch  30, Loss:  8.0000, Regret: 22.1670%
# Epoch  35, Loss:  4.0000, Regret: 21.2154%
# Epoch  40, Loss:  8.7500, Regret: 20.7790%
# Epoch  45, Loss:  7.2500, Regret: 20.4517%
# Epoch  50, Loss:  6.0000, Regret: 20.5063%
# Epoch  55, Loss: 17.7500, Regret: 20.3730%
# Epoch  60, Loss: 14.0000, Regret: 20.3043%
# Epoch  65, Loss:  5.7500, Regret: 20.1729%
# Epoch  70, Loss:  3.7500, Regret: 20.0517%
# Epoch  75, Loss: 14.0000, Regret: 20.0335%
# Epoch  80, Loss:  4.7500, Regret: 20.1224%
# Epoch  85, Loss:  8.2500, Regret: 20.1022%
# Epoch  90, Loss:  4.2500, Regret: 20.2032%
# Epoch  95, Loss: 11.0000, Regret: 20.1871%
# Epoch 100, Loss: 13.2500, Regret: 20.1871%
# Epoch 105, Loss:  3.7500, Regret: 20.2275%
# Epoch 110, Loss:  9.0000, Regret: 20.1871%
# Epoch 115, Loss:  4.0000, Regret: 20.1447%
# Epoch 120, Loss:  8.2500, Regret: 20.0941%
# Epoch 125, Loss:  5.5000, Regret: 20.0962%
# Epoch 130, Loss: 11.5000, Regret: 20.1083%
# Epoch 135, Loss: 18.0000, Regret: 20.0032%
# Epoch 140, Loss:  8.0000, Regret: 20.0881%
# Epoch 145, Loss:  5.0000, Regret: 20.0982%
# Epoch 150, Loss:  2.2500, Regret: 20.1467%
# Epoch 155, Loss: 14.2500, Regret: 20.1063%
# Epoch 160, Loss: 18.2500, Regret: 20.0982%
# Epoch 165, Loss:  2.0000, Regret: 20.1527%
# Epoch 170, Loss: 18.7500, Regret: 20.0679%
# Epoch 175, Loss: 10.0000, Regret: 20.1851%
# Epoch 180, Loss: 10.0000, Regret: 20.2356%
# Epoch 185, Loss:  4.5000, Regret: 20.1790%
# Epoch 190, Loss: 15.2500, Regret: 20.1245%
# Epoch 195, Loss:  4.5000, Regret: 20.1810%
# Epoch 200, Loss: 12.7500, Regret: 20.1770%
# Epoch 205, Loss:  4.0000, Regret: 20.0941%
# Epoch 210, Loss: 17.2500, Regret: 20.1123%
# Epoch 215, Loss:  2.0000, Regret: 20.1366%
# Epoch 220, Loss: 12.5000, Regret: 20.1709%
# Epoch 225, Loss:  9.2500, Regret: 20.1325%
# Epoch 230, Loss:  7.7500, Regret: 20.1184%
# Epoch 235, Loss:  9.5000, Regret: 20.1083%
# Epoch 240, Loss:  3.5000, Regret: 20.0477%
# Epoch 245, Loss: 10.0000, Regret: 19.9648%
# Epoch 250, Loss: 11.0000, Regret: 19.9224%
# Epoch 255, Loss: 13.7500, Regret: 19.8941%
# Epoch 260, Loss: 11.7500, Regret: 19.8032%
# Epoch 265, Loss: 10.2500, Regret: 19.7830%
# Epoch 270, Loss:  9.2500, Regret: 19.7365%
# Epoch 275, Loss:  9.0000, Regret: 19.7487%
# Epoch 280, Loss:  9.0000, Regret: 19.7850%
# Epoch 285, Loss: 12.5000, Regret: 19.7386%
# Epoch 290, Loss:  2.2500, Regret: 19.7325%
# Epoch 295, Loss:  8.0000, Regret: 19.7204%

# %%
# color map
cset =  tc.tol_cset('light')
colors = [cset.light_blue, cset.light_cyan]
# draw plot
fig = plt.figure(figsize=(16, 8))
plt.plot(range(0, 305, 5), loss_r, color=cset.light_blue, ls="-", lw=5, label="DBB")
plt.plot(range(0, 305, 5), loss_h, color=cset.light_cyan, ls=":", lw=5, label="DBB H")
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)
plt.xlabel("Epoch", fontsize=36)
plt.ylabel("Loss", fontsize=36)
plt.title("2D Knapsack", fontsize=36)
plt.legend(fontsize=32)
plt.show()
#fig.savefig("./images/hamming-ks2.pdf", dpi=300)

# %% [markdown]
# ## TSP

# %%
# init data
m = 20 # number of nodes
n = 1000 # number of data
p = 10 # size of feature
deg = 4 # polynomial degree
e = 0.5 # noise half-width
x, c = pyepo.data.tsp.genData(n+1000, p, m, deg=deg, noise_width=e)

# %%
# optimization model 
tsp_model = pyepo.model.grb.tspDFJModel(m)

# %%
# prediction model
reg = LinearRegression(p, m*(m-1)//2)

# %%
# dataset
x_train, x_test, c_train, c_test = train_test_split(x, c, test_size=600, random_state=246)
tsp_dataset_train = pyepo.data.dataset.optDataset(tsp_model, x_train, c_train)
tsp_dataset_test = pyepo.data.dataset.optDataset(tsp_model, x_test, c_test)
# data loader
batch_size = 32
tsp_loader_train = DataLoader(tsp_dataset_train, batch_size=batch_size, shuffle=True)
tsp_loader_test = DataLoader(tsp_dataset_test, batch_size=batch_size, shuffle=False)
# Out:
# Optimizing for optDataset...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 1400/1400 [00:09<00:00, 145.26it/s]
# Optimizing for optDataset...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [00:04<00:00, 143.04it/s]

# %%
# train
loss_h = train_h(tsp_model, copy.deepcopy(reg), tsp_loader_train, tsp_loader_test, num_epochs=600, lr=5e-2)
# Out:
# Num of cores: 4
# Epoch   0, Loss: Unknown, Regret: 181.6178%
# Epoch   0, Loss:  0.1833, Regret: 164.0022%
# Epoch   5, Loss:  0.1873, Regret: 165.5420%
# Epoch  10, Loss:  0.1895, Regret: 162.6855%
# Epoch  15, Loss:  0.1877, Regret: 160.3921%
# Epoch  20, Loss:  0.1873, Regret: 158.2133%
# Epoch  25, Loss:  0.1763, Regret: 160.1772%
# Epoch  30, Loss:  0.1772, Regret: 157.8676%
# Epoch  35, Loss:  0.1789, Regret: 157.7276%
# Epoch  40, Loss:  0.1794, Regret: 155.3632%
# Epoch  45, Loss:  0.1759, Regret: 153.8568%
# Epoch  50, Loss:  0.1776, Regret: 156.6863%
# Epoch  55, Loss:  0.1737, Regret: 150.5375%
# Epoch  60, Loss:  0.1768, Regret: 147.6182%
# Epoch  65, Loss:  0.1680, Regret: 144.6373%
# Epoch  70, Loss:  0.1746, Regret: 145.6129%
# Epoch  75, Loss:  0.1759, Regret: 145.3970%
# Epoch  80, Loss:  0.1746, Regret: 145.8323%
# Epoch  85, Loss:  0.1772, Regret: 146.0741%
# Epoch  90, Loss:  0.1811, Regret: 145.2408%
# Epoch  95, Loss:  0.1719, Regret: 141.8135%
# Epoch 100, Loss:  0.1737, Regret: 141.0932%
# Epoch 105, Loss:  0.1693, Regret: 144.1302%
# Epoch 110, Loss:  0.1724, Regret: 143.3913%
# Epoch 115, Loss:  0.1697, Regret: 142.2327%
# Epoch 120, Loss:  0.1781, Regret: 141.9574%
# Epoch 125, Loss:  0.1706, Regret: 141.5958%
# Epoch 130, Loss:  0.1754, Regret: 141.6467%
# Epoch 135, Loss:  0.1675, Regret: 140.3152%
# Epoch 140, Loss:  0.1711, Regret: 139.0511%
# Epoch 145, Loss:  0.1746, Regret: 139.4016%
# Epoch 150, Loss:  0.1702, Regret: 137.5258%
# Epoch 155, Loss:  0.1693, Regret: 137.6640%
# Epoch 160, Loss:  0.1618, Regret: 136.6311%
# Epoch 165, Loss:  0.1654, Regret: 133.9339%
# Epoch 170, Loss:  0.1592, Regret: 135.2927%
# Epoch 175, Loss:  0.1675, Regret: 134.5666%
# Epoch 180, Loss:  0.1575, Regret: 133.9328%
# Epoch 185, Loss:  0.1711, Regret: 136.6527%
# Epoch 190, Loss:  0.1684, Regret: 132.8015%
# Epoch 195, Loss:  0.1671, Regret: 131.9834%
# Epoch 200, Loss:  0.1667, Regret: 129.9328%
# Epoch 205, Loss:  0.1658, Regret: 131.2224%
# Epoch 210, Loss:  0.1658, Regret: 131.0943%
# Epoch 215, Loss:  0.1702, Regret: 130.9443%
# Epoch 220, Loss:  0.1684, Regret: 129.8049%
# Epoch 225, Loss:  0.1654, Regret: 129.6231%
# Epoch 230, Loss:  0.1689, Regret: 126.9899%
# Epoch 235, Loss:  0.1627, Regret: 125.4651%
# Epoch 240, Loss:  0.1636, Regret: 124.1458%
# Epoch 245, Loss:  0.1623, Regret: 123.7375%
# Epoch 250, Loss:  0.1610, Regret: 123.6484%
# Epoch 255, Loss:  0.1610, Regret: 124.2733%
# Epoch 260, Loss:  0.1654, Regret: 123.0098%
# Epoch 265, Loss:  0.1610, Regret: 123.4985%
# Epoch 270, Loss:  0.1539, Regret: 122.2771%
# Epoch 275, Loss:  0.1671, Regret: 119.9205%
# Epoch 280, Loss:  0.1711, Regret: 121.5622%
# Epoch 285, Loss:  0.1667, Regret: 121.9691%
# Epoch 290, Loss:  0.1640, Regret: 123.2518%
# Epoch 295, Loss:  0.1649, Regret: 120.6494%
# Epoch 300, Loss:  0.1566, Regret: 121.0732%
# Epoch 305, Loss:  0.1658, Regret: 119.7454%
# Epoch 310, Loss:  0.1610, Regret: 117.4626%
# Epoch 315, Loss:  0.1526, Regret: 115.9553%
# Epoch 320, Loss:  0.1675, Regret: 117.4145%
# Epoch 325, Loss:  0.1539, Regret: 115.4461%
# Epoch 330, Loss:  0.1662, Regret: 117.6603%
# Epoch 335, Loss:  0.1522, Regret: 117.0667%
# Epoch 340, Loss:  0.1579, Regret: 117.0936%
# Epoch 345, Loss:  0.1645, Regret: 117.2597%
# Epoch 350, Loss:  0.1601, Regret: 117.5332%
# Epoch 355, Loss:  0.1504, Regret: 116.3815%
# Epoch 360, Loss:  0.1522, Regret: 114.8335%
# Epoch 365, Loss:  0.1618, Regret: 115.5147%
# Epoch 370, Loss:  0.1588, Regret: 114.4190%
# Epoch 375, Loss:  0.1561, Regret: 113.5140%
# Epoch 380, Loss:  0.1728, Regret: 112.9918%
# Epoch 385, Loss:  0.1627, Regret: 113.6249%
# Epoch 390, Loss:  0.1548, Regret: 114.6553%
# Epoch 395, Loss:  0.1531, Regret: 112.8591%
# Epoch 400, Loss:  0.1618, Regret: 113.1063%
# Epoch 405, Loss:  0.1566, Regret: 112.8688%
# Epoch 410, Loss:  0.1627, Regret: 111.9594%
# Epoch 415, Loss:  0.1627, Regret: 115.0613%
# Epoch 420, Loss:  0.1531, Regret: 112.9945%
# Epoch 425, Loss:  0.1605, Regret: 112.1421%
# Epoch 430, Loss:  0.1566, Regret: 110.1658%
# Epoch 435, Loss:  0.1544, Regret: 112.8802%
# Epoch 440, Loss:  0.1605, Regret: 113.8947%
# Epoch 445, Loss:  0.1649, Regret: 112.5329%
# Epoch 450, Loss:  0.1636, Regret: 112.8934%
# Epoch 455, Loss:  0.1592, Regret: 113.2758%
# Epoch 460, Loss:  0.1561, Regret: 114.2062%
# Epoch 465, Loss:  0.1583, Regret: 115.2983%
# Epoch 470, Loss:  0.1557, Regret: 112.8205%
# Epoch 475, Loss:  0.1579, Regret: 113.3269%
# Epoch 480, Loss:  0.1583, Regret: 112.1120%
# Epoch 485, Loss:  0.1570, Regret: 111.8861%
# Epoch 490, Loss:  0.1566, Regret: 111.9692%
# Epoch 495, Loss:  0.1623, Regret: 111.9692%
# Epoch 500, Loss:  0.1544, Regret: 111.9692%
# Epoch 505, Loss:  0.1548, Regret: 111.9692%
# Epoch 510, Loss:  0.1583, Regret: 111.9692%
# Epoch 515, Loss:  0.1618, Regret: 111.9692%
# Epoch 520, Loss:  0.1605, Regret: 111.9692%
# Epoch 525, Loss:  0.1509, Regret: 111.9692%
# Epoch 530, Loss:  0.1588, Regret: 111.9692%
# Epoch 535, Loss:  0.1513, Regret: 111.9692%
# Epoch 540, Loss:  0.1509, Regret: 111.9692%
# Epoch 545, Loss:  0.1575, Regret: 111.9692%
# Epoch 550, Loss:  0.1509, Regret: 111.9692%
# Epoch 555, Loss:  0.1548, Regret: 111.9692%
# Epoch 560, Loss:  0.1680, Regret: 111.9692%
# Epoch 565, Loss:  0.1649, Regret: 111.9692%
# Epoch 570, Loss:  0.1518, Regret: 111.9692%
# Epoch 575, Loss:  0.1566, Regret: 111.9692%
# Epoch 580, Loss:  0.1601, Regret: 112.1899%
# Epoch 585, Loss:  0.1496, Regret: 112.6671%
# Epoch 590, Loss:  0.1570, Regret: 110.2488%
# Epoch 595, Loss:  0.1469, Regret: 111.7826%

# %%
# train
loss_r = train_r(tsp_model, copy.deepcopy(reg), tsp_loader_train, tsp_loader_test, lr=5e-2)
# Out:
# Num of cores: 4
# Epoch   0, Loss: Unknown, Regret: 181.6178%
# Epoch   0, Loss:  5.4338, Regret: 11.4278%
# Epoch   5, Loss:  4.1982, Regret:  9.2682%
# Epoch  10, Loss:  4.0214, Regret:  9.0946%
# Epoch  15, Loss:  3.9922, Regret:  8.1737%
# Epoch  20, Loss:  3.3611, Regret:  7.6623%
# Epoch  25, Loss:  3.7383, Regret:  7.8791%
# Epoch  30, Loss:  3.9864, Regret:  7.3279%
# Epoch  35, Loss:  2.4861, Regret:  7.3153%
# Epoch  40, Loss:  2.6958, Regret:  7.1222%
# Epoch  45, Loss:  2.4602, Regret:  7.0247%
# Epoch  50, Loss:  3.5002, Regret:  7.1084%
# Epoch  55, Loss:  2.6328, Regret:  7.1327%
# Epoch  60, Loss:  2.4975, Regret:  7.3847%
# Epoch  65, Loss:  2.4902, Regret:  7.4468%
# Epoch  70, Loss:  2.7420, Regret:  7.1634%
# Epoch  75, Loss:  2.6363, Regret:  7.0620%
# Epoch  80, Loss:  2.7686, Regret:  7.0847%
# Epoch  85, Loss:  2.5521, Regret:  7.1598%
# Epoch  90, Loss:  2.2438, Regret:  7.3222%
# Epoch  95, Loss:  2.5132, Regret:  6.9432%
# Epoch 100, Loss:  2.5836, Regret:  7.0044%
# Epoch 105, Loss:  1.9655, Regret:  7.2946%
# Epoch 110, Loss:  2.6004, Regret:  6.8392%
# Epoch 115, Loss:  2.3433, Regret:  6.8282%
# Epoch 120, Loss:  2.7910, Regret:  6.9573%
# Epoch 125, Loss:  2.1723, Regret:  7.0799%
# Epoch 130, Loss:  2.2178, Regret:  7.0522%
# Epoch 135, Loss:  2.7951, Regret:  6.9150%
# Epoch 140, Loss:  3.1213, Regret:  6.7188%
# Epoch 145, Loss:  1.9374, Regret:  7.1350%
# Epoch 150, Loss:  3.0879, Regret:  6.6084%
# Epoch 155, Loss:  2.8049, Regret:  6.5432%
# Epoch 160, Loss:  2.0538, Regret:  6.9749%
# Epoch 165, Loss:  2.7240, Regret:  6.9892%
# Epoch 170, Loss:  1.9065, Regret:  7.0079%
# Epoch 175, Loss:  2.4930, Regret:  6.9183%
# Epoch 180, Loss:  2.3763, Regret:  6.8389%
# Epoch 185, Loss:  3.3231, Regret:  7.0535%
# Epoch 190, Loss:  2.1824, Regret:  7.0475%
# Epoch 195, Loss:  2.5588, Regret:  6.8676%
# Epoch 200, Loss:  1.6655, Regret:  6.7429%
# Epoch 205, Loss:  2.3366, Regret:  6.7958%
# Epoch 210, Loss:  2.4378, Regret:  6.6993%
# Epoch 215, Loss:  2.4632, Regret:  6.8138%
# Epoch 220, Loss:  2.0507, Regret:  7.0896%
# Epoch 225, Loss:  2.1433, Regret:  6.9430%
# Epoch 230, Loss:  1.7977, Regret:  6.7723%
# Epoch 235, Loss:  1.6912, Regret:  6.9860%
# Epoch 240, Loss:  2.0186, Regret:  6.7485%
# Epoch 245, Loss:  2.0066, Regret:  6.9986%
# Epoch 250, Loss:  1.6659, Regret:  6.9479%
# Epoch 255, Loss:  2.4345, Regret:  6.8212%
# Epoch 260, Loss:  1.7519, Regret:  6.8296%
# Epoch 265, Loss:  2.2198, Regret:  6.7205%
# Epoch 270, Loss:  2.5321, Regret:  6.7794%
# Epoch 275, Loss:  1.8582, Regret:  7.0359%
# Epoch 280, Loss:  2.7919, Regret:  6.5351%
# Epoch 285, Loss:  2.4130, Regret:  6.7834%
# Epoch 290, Loss:  2.5421, Regret:  6.8355%
# Epoch 295, Loss:  2.2891, Regret:  7.0041%

# %%
# color map
cset =  tc.tol_cset('light')
colors = [cset.light_blue, cset.light_cyan]
# draw plot
fig = plt.figure(figsize=(16, 8))
plt.plot(range(0, 305, 5), loss_r, color=cset.light_blue, ls="-", lw=5, label="DBB")
plt.plot(range(0, 605, 5), loss_h, color=cset.light_cyan, ls=":", lw=5, label="DBB H")
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)
plt.xlabel("Epoch", fontsize=36)
plt.ylabel("Loss", fontsize=36)
plt.title("Travelling Salesman", fontsize=36)
plt.legend(fontsize=32)
plt.show()
#fig.savefig("./images/hamming-tsp.pdf", dpi=300)
