# %%
# set work dir
import os
os.chdir("../")

# %%
from copy import deepcopy
from types import SimpleNamespace

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import scienceplots
plt.style.reload_library()
plt.style.use("science")
from matplotlib import ticker
import tol_colors as tc

from run import utils
# Out:
# Auto-Sklearn cannot be imported.

# %%
# ignore warning
import warnings
warnings.filterwarnings('ignore')

# %%
# init config
config = SimpleNamespace()
config.prob = "ks"
config.item = 32
config.dim = 2
config.cap = 20
config.feat = 5
config.net = []
config.optm = "adam"
config.batch = 32
config.l1 = 0.0
config.l2 = 0.0
config.rel = False
config.lan = "gurobi"
config.proc = 32
config.path = "./res"

# %%
# polynomial degree
degs = [2, 6]

# %%
def getPath(config, mthd):
    config = deepcopy(config)
    if mthd == "spo":
        config.mthd = "spo"
        config.lr = 1e-2
        config.sftp = False
    if mthd == "spo rel":
        config.mthd = "spo"
        config.lr = 1e-2
        config.rel = True
        config.sftp = False
    if mthd == "dbb":
        config.mthd = "dbb"
        config.loss = "r"
        config.lr = 1e-1
        config.smth = 20
        config.sftp = False
    if mthd == "dbb rel":
        config.mthd = "dbb"
        config.loss = "r"
        config.lr = 1e-1
        config.smth = 20
        config.rel = True
        config.sftp = False
    if mthd == "dpo":
        config.mthd = "dpo"
        config.batch = 32
        config.lr = 1e-2
        config.samp = 1
        config.eps = 1.0
        config.sftp = False
    if mthd == "dpo rel":
        config.mthd = "dpo"
        config.batch = 32
        config.lr = 1e-2
        config.samp = 1
        config.eps = 1.0
        config.rel = True
        config.sftp = False
    if mthd == "pfyl":
        config.mthd = "pfyl"
        config.batch = 32
        config.lr = 1e-2
        config.samp = 1
        config.eps = 1.0
        config.sftp = False
    if mthd == "pfyl rel":
        config.mthd = "pfyl"
        config.batch = 32
        config.lr = 1e-2
        config.samp = 1
        config.eps = 1.0
        config.rel = True
        config.sftp = False
    path = utils.getSavePath(config)
    return path

# %%
def getDf(config, degs, mthd, col="Unamb SPO"):
    dfs = pd.DataFrame()
    for deg in degs:
        config.deg = deg
        df = pd.read_csv(getPath(config, mthd))
        dfs[deg] = df[col]
    return dfs

# %%
def getElapsed(config):
    df = pd.DataFrame(columns=["Method", "Data Size", "Noise", "Elapsed_mean", "Elapsed_std"])
    for mthd in ["spo", "spo rel", "dbb", "dbb rel", "dpo", "dpo rel", "pfyl", "pfyl rel"]:
        elapses = np.empty((1,0))
        for noise in [0.0, 0.5]:
            config = deepcopy(config)
            config.noise = noise
            for data in [100, 1000, 5000]:
                # get df
                config.data = data
                cur_df = getDf(config, degs, mthd, "Elapsed")
                # per iter
                if data == 100:
                    cur_df = getDf(config, degs, mthd, "Elapsed").to_numpy() / 200 / np.ceil(data / config.batch)
                if data == 1000:
                    cur_df = getDf(config, degs, mthd, "Elapsed").to_numpy() / 20 / np.ceil(data / config.batch)
                if data == 5000:
                    cur_df = getDf(config, degs, mthd, "Elapsed").to_numpy() / 4 / np.ceil(data / config.batch)
                    elapses = np.concatenate((elapses, cur_df.reshape(1,-1)), axis=1)
        # stat
        elapsed_mean = elapses.mean()
        elapsed_std = elapses.std()
        row = {"Method":mthd, "Data Size":data, "Noise":noise, "Elapsed_mean":elapsed_mean, "Elapsed_std":elapsed_std}
        df = df.append(row, ignore_index=True)
    # list
    means, stds = [], []
    for mthd in ["spo", "spo rel", "dbb", "dbb rel", "dpo", "dpo rel", "pfyl", "pfyl rel"]:
        means.append(df[df["Method"]==mthd]["Elapsed_mean"].values[0])
        stds.append(df[df["Method"]==mthd]["Elapsed_std"].values[0])
    return means, stds

# %%
def lighten(color, amount=0.9):
    """
    Lightens the given color by multiplying (1-luminosity) by the given amount.
    """
    import matplotlib.colors as mc
    import colorsys
    try:
        c = mc.cnames[color]
    except:
        c = color
    c = np.array(colorsys.rgb_to_hls(*mc.to_rgb(c)))
    return colorsys.hls_to_rgb(c[0],1-amount * (1-c[1]),c[2])

# %%
def drawBarPlot(config):
    val, err = getElapsed(config)
    # color map
    cmap = tc.tol_cmap("rainbow_discrete")(np.linspace(0, 1, 22))
    colors = [cmap[16], cmap[14], cmap[7], cmap[9], cmap[10], cmap[12], cmap[5], cmap[3]]
    for i in range(len(colors)):
        colors[i] = lighten(colors[i])
    # draw boxplot
    fig = plt.figure(figsize=(16,6))
    x = np.array(range(8))
    plt.bar(x, height=val, width=0.6, edgecolor="w",
                   linewidth=3, color=colors, label="Training Set Size = 1000")
    plt.errorbar(x, val, yerr=err, capsize=5, capthick=2, linestyle="", marker="o",
                 markersize=3, color="k", elinewidth=2, alpha=0.7)
    # grid
    plt.grid(color="grey", alpha=0.5, linewidth=0.5, which="major", axis="y")
    # labels and ticks
    plt.xlim(-0.5, 7.5)
    #plt.ylim(0.0, 125)
    plt.xticks(ticks=[0,1,2,3,4,5,6,7], fontsize=22,
               labels=["SPO+", "SPO+ Rel", "DBB", "DBB Rel", "DPO", "DPO Rel", "PFYL", "PFYL Rel"])
    plt.xlabel("Method", fontsize=36)
    plt.ylabel("Runtime per Iter (Sec)", fontsize=36)
    plt.yticks(fontsize=24)
    plt.title("2D Knapsack", fontsize=30)
    # save
    plt.show()
    fig.savefig("./images/rel-ks2-time.pdf", dpi=300)

# %%
def drawPlot(config, data, noise):
    # set config
    config = deepcopy(config)
    config.data = data
    config.noise = noise
    # get df
    df_spo      = getDf(config, degs, "spo")
    df_spo_rel  = getDf(config, degs, "spo rel")
    df_dbb      = getDf(config, degs, "dbb")
    df_dbb_rel  = getDf(config, degs, "dbb rel")
    df_dpo      = getDf(config, degs, "dpo")
    df_dpo_rel  = getDf(config, degs, "dpo rel")
    df_pfyl     = getDf(config, degs, "pfyl")
    df_pfyl_rel = getDf(config, degs, "pfyl rel")
    # color map
    cmap = tc.tol_cmap("rainbow_discrete")(np.linspace(0, 1, 22))
    colors = [cmap[16], cmap[14], cmap[7], cmap[9], cmap[10], cmap[12], cmap[5], cmap[3]]
    for i in range(len(colors)):
        colors[i] = lighten(colors[i])
    # draw boxplot
    fig = plt.figure(figsize=(16,6))
    #######################################################################################################################
    c = colors[0]
    bp1 = plt.boxplot(df_spo, boxprops=dict(facecolor=c, color=c, linewidth=4), medianprops=dict(color="w", linewidth=2),
                      whiskerprops=dict(color=c, linewidth=2), capprops=dict(color=c, linewidth=2),
                      flierprops=dict(markeredgecolor=c, marker="o", markersize=5, markeredgewidth=2),
                      patch_artist=True, positions=np.arange(df_spo.shape[1])-0.42, widths=0.10)
    c = colors[1]
    bp2 = plt.boxplot(df_spo_rel, boxprops=dict(facecolor=c, color=c, linewidth=4), medianprops=dict(color="w", linewidth=2),
                      whiskerprops=dict(color=c, linewidth=2), capprops=dict(color=c, linewidth=2),
                      flierprops=dict(markeredgecolor=c, marker="o", markersize=5, markeredgewidth=2),
                      patch_artist=True, positions=np.arange(df_spo.shape[1])-0.30, widths=0.10)
    #######################################################################################################################
    c = colors[2]
    bp3 = plt.boxplot(df_dbb, boxprops=dict(facecolor=c, color=c, linewidth=4), medianprops=dict(color="w", linewidth=2),
                      whiskerprops=dict(color=c, linewidth=2), capprops=dict(color=c, linewidth=2),
                      flierprops=dict(markeredgecolor=c, marker="o", markersize=5, markeredgewidth=2),
                      patch_artist=True, positions=np.arange(df_dbb.shape[1])-0.18, widths=0.10)
    c = colors[3]
    bp4 = plt.boxplot(df_dbb_rel, boxprops=dict(facecolor=c, color=c, linewidth=4), medianprops=dict(color="w", linewidth=2),
                      whiskerprops=dict(color=c, linewidth=2), capprops=dict(color=c, linewidth=2),
                      flierprops=dict(markeredgecolor=c, marker="o", markersize=5, markeredgewidth=2),
                      patch_artist=True, positions=np.arange(df_dbb.shape[1])-0.06, widths=0.10) 
    #######################################################################################################################
    c = colors[4]
    bp5 = plt.boxplot(df_dpo, boxprops=dict(facecolor=c, color=c, linewidth=4), medianprops=dict(color="w", linewidth=2),
                      whiskerprops=dict(color=c, linewidth=2), capprops=dict(color=c, linewidth=2),
                      flierprops=dict(markeredgecolor=c, marker="o", markersize=5, markeredgewidth=2),
                      patch_artist=True, positions=np.arange(df_dbb.shape[1])+0.06, widths=0.10)
    c = colors[5]
    bp6 = plt.boxplot(df_dpo_rel, boxprops=dict(facecolor=c, color=c, linewidth=4), medianprops=dict(color="w", linewidth=2),
                      whiskerprops=dict(color=c, linewidth=2), capprops=dict(color=c, linewidth=2),
                      flierprops=dict(markeredgecolor=c, marker="o", markersize=5, markeredgewidth=2),
                      patch_artist=True, positions=np.arange(df_dbb.shape[1])+0.18, widths=0.10) 
    #######################################################################################################################
    c = colors[6]
    bp7 = plt.boxplot(df_pfyl, boxprops=dict(facecolor=c, color=c, linewidth=4), medianprops=dict(color="w", linewidth=2),
                      whiskerprops=dict(color=c, linewidth=2), capprops=dict(color=c, linewidth=2),
                      flierprops=dict(markeredgecolor=c, marker="o", markersize=5, markeredgewidth=2),
                      patch_artist=True, positions=np.arange(df_dbb.shape[1])+0.30, widths=0.10)
    c = colors[7]
    bp8 = plt.boxplot(df_pfyl_rel, boxprops=dict(facecolor=c, color=c, linewidth=4), medianprops=dict(color="w", linewidth=2),
                      whiskerprops=dict(color=c, linewidth=2), capprops=dict(color=c, linewidth=2),
                      flierprops=dict(markeredgecolor=c, marker="o", markersize=5, markeredgewidth=2),
                      patch_artist=True, positions=np.arange(df_dbb.shape[1])+0.42, widths=0.10) 
    # vertical line
    plt.axvline(x=0.5, color="k", linestyle="--", linewidth=1.5)
    #plt.axvline(x=1.5, color="k", linestyle="--", linewidth=1.5)
    #plt.axvline(x=2.5, color="k", linestyle="--", linewidth=1.5)
    # grid
    plt.grid(color="grey", alpha=0.5, linewidth=0.5, which="major", axis="y")
    # labels and ticks
    plt.xlabel("Polynomial Degree", fontsize=36)
    plt.xticks(ticks=range(len(degs)), labels=degs, fontsize=28)
    plt.ylabel("Normalized Regret", fontsize=36)
    plt.yticks(fontsize=24)
    plt.xlim(-0.5, 1.5)
    plt.ylim(-0.01, 0.39)
    ax = plt.gca()
    ax.yaxis.set_major_formatter(ticker.FormatStrFormatter("%.2f"))
    plt.title("Training Set Size = {},\nNoise Half−width = {}".format(config.data, config.noise), fontsize=30)
    plt.legend([bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0], bp4["boxes"][0], 
                bp5["boxes"][0], bp6["boxes"][0], bp7["boxes"][0], bp8["boxes"][0]],
               ["SPO+", "SPO+ Rel", "DBB", "DBB Rel", "DPO", "DPO Rel", "PFYL", "PFYL Rel"],
               fontsize=20, loc=2, labelspacing=0.2, handlelength=1, ncol=4)
    # save
    plt.show()
    fig.savefig("./images/rel-ks2-n{}e{}.pdf".format(data,int(10*noise)), dpi=300)

# %% [markdown]
# ## Elapsed Time

# %%
drawBarPlot(config)

# %% [markdown]
# ## n = 100, e = 0

# %%
drawPlot(config, data=100, noise=0.0)

# %% [markdown]
# ## n = 100, e = 0

# %%
drawPlot(config, data=100, noise=0.5)

# %% [markdown]
# ## n = 1000, e = 0

# %%
drawPlot(config, data=1000, noise=0.0)

# %% [markdown]
# ## n = 1000, e = 0.5

# %%
drawPlot(config, data=1000, noise=0.5)

# %% [markdown]
# ## n = 5000, e = 0

# %%
drawPlot(config, data=5000, noise=0.0)

# %% [markdown]
# ## n = 5000, e = 0.5

# %%
drawPlot(config, data=5000, noise=0.5)
