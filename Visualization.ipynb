# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## n = 100, e = 0

# %%
df_spo = pd.read_csv('./res/spoplus_n100.csv')
df_bb = pd.read_csv('./res/blackbox_n100.csv')

# %%
# draw boxplot
plt.figure(figsize=(12,6))
plt.boxplot(df_spo, boxprops=dict(facecolor='c', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])-0.2, widths=0.4)
plt.boxplot(df_bb, boxprops=dict(facecolor='m', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])+0.2, widths=0.4)
plt.xlabel('Deg', fontsize=16)
plt.xticks(ticks=[0,1,2,3], labels=[1,2,4,6], fontsize=12)
plt.ylabel('Normalized SPO Loss', fontsize=16)
plt.yticks(fontsize=12)
plt.ylim(0, 0.5)
plt.title('Training Set Size = 100,\nNoise Half−width = 0')
plt.legend(['SPO+','Black-Box'], labelcolor=['c','m'])
plt.show()

# %% [markdown]
# ## n = 100, e = 0.5

# %%
df_spo = pd.read_csv('./res/spoplus_n100_noise.csv')
df_bb = pd.read_csv('./res/blackbox_n100_noise.csv')

# %%
# draw boxplot
plt.figure(figsize=(12,6))
plt.boxplot(df_spo, boxprops=dict(facecolor='c', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])-0.2, widths=0.4)
plt.boxplot(df_bb, boxprops=dict(facecolor='m', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])+0.2, widths=0.4)
plt.xlabel('Deg', fontsize=16)
plt.xticks(ticks=[0,1,2,3], labels=[1,2,4,6], fontsize=12)
plt.ylabel('Normalized SPO Loss', fontsize=16)
plt.yticks(fontsize=12)
plt.ylim(0, 0.5)
plt.title('Training Set Size = 100,\nNoise Half−width = 0.5')
plt.legend(['SPO+','Black-Box'], labelcolor=['c','m'])
plt.show()

# %% [markdown]
# # n = 1000, e = 0

# %%
df_spo = pd.read_csv('./res/spoplus_n1000.csv')
df_bb = pd.read_csv('./res/blackbox_n1000.csv')

# %%
# draw boxplot
plt.figure(figsize=(12,6))
plt.boxplot(df_spo, boxprops=dict(facecolor='c', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])-0.2, widths=0.4)
plt.boxplot(df_bb, boxprops=dict(facecolor='m', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])+0.2, widths=0.4)
plt.xlabel('Deg', fontsize=16)
plt.xticks(ticks=[0,1,2,3], labels=[1,2,4,6], fontsize=12)
plt.ylabel('Normalized SPO Loss', fontsize=16)
plt.yticks(fontsize=12)
plt.ylim(0, 0.5)
plt.title('Training Set Size = 1000,\nNoise Half−width = 0')
plt.legend(['SPO+','Black-Box'], labelcolor=['c','m'])
plt.show()

# %% [markdown]
# ## n = 1000, e = 0.5

# %%
df_spo = pd.read_csv('./res/spoplus_n1000_noise.csv')
df_bb = pd.read_csv('./res/blackbox_n1000_noise.csv')

# %%
# draw boxplot
plt.figure(figsize=(12,6))
plt.boxplot(df_spo, boxprops=dict(facecolor='c', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])-0.2, widths=0.4)
plt.boxplot(df_bb, boxprops=dict(facecolor='m', color='k'), medianprops=dict(color='k'), 
            patch_artist=True, positions=np.arange(df_spo.shape[1])+0.2, widths=0.4)
plt.xlabel('Deg', fontsize=16)
plt.xticks(ticks=[0,1,2,3], labels=[1,2,4,6], fontsize=12)
plt.ylabel('Normalized SPO Loss', fontsize=16)
plt.yticks(fontsize=12)
plt.ylim(0, 0.5)
plt.title('Training Set Size = 1000,\nNoise Half−width = 0.5')
plt.legend(['SPO+','Black-Box'], labelcolor=['c','m'])
plt.show()
